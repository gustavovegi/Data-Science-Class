# %%
# %pip install pandas
# Out:
# ...
#                                               0.0/11.6 MB ? eta -:--:--
#                                               0.2/11.6 MB 3.9 MB/s eta 0:00:03
#      --                                       0.8/11.6 MB 8.2 MB/s eta 0:00:02
#      ----                                     1.4/11.6 MB 10.1 MB/s eta 0:00:02
#      -------                                  2.3/11.6 MB 12.0 MB/s eta 0:00:01
#      -----------                              3.3/11.6 MB 14.3 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
#      ------------                             3.6/11.6 MB 15.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd 
mark = pd.read_csv(r"Dados3 Marketing.csv", sep=';')
print(mark.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
import pandas as pd 
fraudes= pd.read_csv(r"Dados1 Cartoes.csv", sep=';')
print(fraudes.info)
# Out:
# <bound method DataFrame.info of        distance_from_home,distance_from_last_transaction,ratio_to_median_purchase_price,repeat_retailer,used_chip,used_pin_number,online_order,fraud
# 0       57.87785658389723,0.3111400080477545,1.9459399...
# 1       10.829942699255545,0.17559150228166587,1.29421...
# 2       5.091079490616996,0.8051525945853258,0.4277145...
# 3       2.2475643282963613,5.60004354707232,0.36266257...
# 4       44.19093600261837,0.5664862680583477,2.2227672...
# ...                                                   ...
# 999995  2.2071007085956595,0.11265130279473716,1.62679...
# 999996  19.872725762075127,2.6839037264517254,2.778302...
# 999997  2.914856986796768,1.4726866870566833,0.2180754...
# 999998  4.258729391720518,0.24202336594551443,0.475822...
# 999999  58.10812496080576,0.3181101207150046,0.3869198...
#
# [1000000 rows x 1 columns]>

# %%
fraudes_dist = fraudes.sort_values('distance_from_home')

# %%
print(fraudes.tail())
print("-------------------------------------------------------")
print(fraudes_dist.tail())

# %%
print(mark.tail())
print("-------------------------------------------------------")
print("-------------------------------------------------------")
print("-------------------------------------------------------")
print(mark)

# %%
mark_age = mark.sort_values('age')

# %%
print(mark_age.head(10))
print(mark_age.tail(10))
# Out:
#        age      job marital    education default  housing     loan    contact  \
# 38274   17  student  single      unknown      no       no      yes   cellular
# 37579   17  student  single     basic.9y      no  unknown  unknown   cellular
# 37539   17  student  single     basic.9y      no      yes       no   cellular
# 37140   17  student  single      unknown      no      yes       no   cellular
# 37558   17  student  single     basic.9y      no      yes       no   cellular
# 38832   18  student  single  high.school      no       no       no   cellular
# 24110   18  student  single  high.school      no       no       no  telephone
# 37626   18  student  single     basic.6y      no      yes       no   cellular
# 27792   18  student  single  high.school      no      yes      yes   cellular
# 37955   18  student  single      unknown      no      yes       no   cellular
#
#       month day_of_week  ...  campaign  pdays  previous     poutcome  \
# ...

# %%
mark_age_edu = mark.sort_values(['age', 'education'])

# %%
print(mark_age_edu.head(10))
print(mark_age_edu.tail(10))
# Out:
#        age      job marital education default  housing     loan    contact  \
# 37539   17  student  single  basic.9y      no      yes       no   cellular
# 37558   17  student  single  basic.9y      no      yes       no   cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown   cellular
# 37140   17  student  single   unknown      no      yes       no   cellular
# 38274   17  student  single   unknown      no       no      yes   cellular
# 30142   18  student  single  basic.4y      no       no       no   cellular
# 30349   18  student  single  basic.4y      no      yes      yes   cellular
# 39903   18  student  single  basic.4y      no      yes       no   cellular
# 41088   18  student  single  basic.4y      no      yes       no  telephone
# 37626   18  student  single  basic.6y      no      yes       no   cellular
#
#       month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 37539   aug         fri  ...         2    999         2      failure
# ...

# %%
mark_age = mark.sort_values('age', ascending=False)

# %%
print(mark_age.head(10))
print(mark_age.tail(10))
# Out:
#        age      job   marital          education  default housing loan  \
# 38452   98  retired   married           basic.4y  unknown     yes   no
# 38455   98  retired   married           basic.4y  unknown     yes   no
# 27826   95  retired  divorced           basic.6y       no      no   no
# 38921   94  retired   married           basic.9y       no      no   no
# 39655   92  retired   married            unknown       no     yes   no
# 40450   92  retired   married            unknown       no      no  yes
# 39734   92  retired  divorced            unknown  unknown      no   no
# 40469   92  retired   married            unknown       no      no  yes
# 38032   91  retired   married  university.degree       no      no  yes
# 38022   91  retired   married  university.degree       no     yes  yes
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 38452  cellular   oct         fri  ...         1      2         2
# ...

# %%
mark.sort_index(['age', 'education', 'marital'], ascending=False, inplace=True)

# %%
print(mark.head())
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
mark_married = mark[mark['marital'] == 'marreid']
print(mark_married)
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
mark_unemp = mark[mark['job'] == 'unemployed']
print(mark_unemp)
# Out:
#        age         job  marital            education  default housing loan  \
# 20      30  unemployed  married          high.school       no      no   no
# 58      55  unemployed  married  professional.course  unknown     yes  yes
# 93      33  unemployed  married             basic.9y       no      no   no
# 111     58  unemployed  married             basic.4y  unknown      no   no
# 140     43  unemployed   single    university.degree       no     yes   no
# ...    ...         ...      ...                  ...      ...     ...  ...
# 41032   36  unemployed  married          high.school       no     yes   no
# 41132   41  unemployed  married             basic.9y       no      no   no
# 41136   54  unemployed  married  professional.course       no     yes   no
# 41138   58  unemployed  married    university.degree       no     yes   no
# 41182   29  unemployed   single             basic.4y       no     yes   no
#
# ...

# %%
mark_50 = mark[mark['age'] > 49]
print(mark_50)
# Out:
#        age        job   marital            education  default housing loan  \
# 0       56  housemaid   married             basic.4y       no      no   no
# 1       57   services   married          high.school  unknown      no   no
# 4       56   services   married          high.school       no      no  yes
# 6       59     admin.   married  professional.course       no      no   no
# 13      57  housemaid  divorced             basic.4y       no     yes   no
# ...    ...        ...       ...                  ...      ...     ...  ...
# 41178   62    retired   married    university.degree       no      no   no
# 41179   64    retired  divorced  professional.course       no     yes   no
# 41183   73    retired   married  professional.course       no     yes   no
# 41185   56    retired   married    university.degree       no     yes   no
# 41187   74    retired   married  professional.course       no     yes   no
#
# ...
